# %% [markdown]
# # 05 Attributes Models Experiments
#
# Purpose: inspect attribute extractor interface behavior, checkpoint-backed loading, and output dictionaries.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parents[0] if (Path.cwd() / 'mcmt_core').exists() else Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from mcmt_core.attributes import AttributeBaseline, PersonAttributeExtractor, build_attribute_extractor
print('Attribute imports ready')
