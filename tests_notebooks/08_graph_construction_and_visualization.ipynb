# %% [markdown]
# # 08 Graph Construction and Visualization
#
# Purpose: inspect graph construction, node counts, edge counts, rendered graph views, and the graph-debug sink outputs.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parents[0] if (Path.cwd() / 'mcmt_core').exists() else Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from mcmt_core.features import EdgeFeatureBuilder, NodeFeatureBuilder
from mcmt_core.graphs import build_spatial_frame_graph
from mcmt_core.outputs import GraphDebugSink
print('Graph notebook imports ready')
