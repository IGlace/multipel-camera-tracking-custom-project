# %% [markdown]
# # 04 ReID Models Experiments
#
# Purpose: inspect ReID extractor interface behavior, checkpoint-backed loading, and embedding outputs.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parents[0] if (Path.cwd() / 'mcmt_core').exists() else Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from mcmt_core.reid import MGN, MGNReIDExtractor, build_reid_extractor
print('ReID imports ready')
