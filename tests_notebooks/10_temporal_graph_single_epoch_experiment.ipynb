# %% [markdown]
# # 10 Temporal Graph Single Epoch Experiment
#
# Purpose: run a small temporal-graph neural sanity experiment and inspect model outputs, tensor shapes, and graph statistics.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parents[0] if (Path.cwd() / 'mcmt_core').exists() else Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from mcmt_core.graphs import GraphTensorBatch, build_reasoning_module
print('Temporal graph neural imports ready')
