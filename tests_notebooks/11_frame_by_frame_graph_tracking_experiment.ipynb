# %% [markdown]
# # 11 Frame by Frame Graph Tracking Experiment
#
# Purpose: inspect frame-based graph tracking outputs across multiple timestamps, including direct-score and neural-edge inference variants.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parents[0] if (Path.cwd() / 'mcmt_core').exists() else Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from mcmt_core.graphs import infer_graph_edge_probabilities
print('Frame graph tracking notebook imports ready')
